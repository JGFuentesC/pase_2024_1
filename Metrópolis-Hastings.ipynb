# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %% [markdown]
# ## Simular números normales estándar

# %%
delta = 0.5
T = 10000

X =[]
X.append(0)

for i in range(1,T):
    eps = np.random.uniform(-delta,delta)
    y = X[i-1]+eps
    alpha = min([(stats.norm.pdf(y))/(stats.norm.pdf(X[i-1])),1])
    u = np.random.uniform()
    if u <=alpha:
        X.append(y)
    else:
        X.append(X[i-1])

sns.distplot(X)
sns.distplot(np.random.normal(size=T))
plt.figure()
plt.plot(X)
# Out:
# /tmp/ipykernel_4921/1366036409.py:17: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(X)
# /tmp/ipykernel_4921/1366036409.py:18: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.random.normal(size=T))

# %% [markdown]
# ## Simular Números $X\sim\exp(\lambda=2)$

# %%
delta = 0.5
T = 10000

X =[]
X.append(0)

for i in range(1,T):
    eps = np.random.uniform(-delta,delta)
    y = X[i-1]+eps
    alpha = min([(stats.expon(scale=1/2).pdf(y))/(stats.expon(scale=1/2).pdf(X[i-1])),1])
    u = np.random.uniform()
    if u <=alpha:
        X.append(y)
    else:
        X.append(X[i-1])

sns.distplot(X)
sns.distplot(np.random.exponential(scale=1/2,size=T))
plt.figure()
plt.plot(X)
# Out:
# /tmp/ipykernel_4921/1542590586.py:17: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(X)
# /tmp/ipykernel_4921/1542590586.py:18: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.random.exponential(scale=1/2,size=T))

# %% [markdown]
# ## Simular Números $F_{\nu_1=4,\nu_2=23}$

# %%
delta = 0.5
T = 10000

X =[]
X.append(0)

for i in range(1,T):
    eps = np.random.uniform(-delta,delta)
    y = X[i-1]+eps
    alpha = min([(stats.f(4,23).pdf(y))/(stats.f(4,23).pdf(X[i-1])),1])
    u = np.random.uniform()
    if u <=alpha:
        X.append(y)
    else:
        X.append(X[i-1])

sns.distplot(X)
sns.distplot(np.random.f(4,23,size=T))
plt.figure()
plt.plot(X)
# Out:
# /tmp/ipykernel_4921/3711834541.py:10: RuntimeWarning: divide by zero encountered in scalar divide
#   alpha = min([(stats.f(4,23).pdf(y))/(stats.f(4,23).pdf(X[i-1])),1])
# /tmp/ipykernel_4921/3711834541.py:17: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(X)
# /tmp/ipykernel_4921/3711834541.py:18: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# ...
